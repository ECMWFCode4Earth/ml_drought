# %%
# %matplotlib inline
import xarray as xr
import matplotlib.pyplot as plt

# %%
x = xr.open_dataset('data/features/train/2017_6/x.nc')

# %%
y = xr.open_dataset('data/features/train/2017_6/y.nc')

# %%
x
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 224, lon: 176, time: 11)
# Coordinates:
#   * time     (time) datetime64[ns] 2016-07-31 2016-08-31 ... 2017-05-31
#   * lat      (lat) float32 -5.175003 -5.125 -5.075001 ... 5.924999 5.9749985
#   * lon      (lon) float32 33.524994 33.574997 33.625 ... 42.22499 42.274994
# Data variables:
#     precip   (time, lat, lon) float32 ...
#     VHI      (time, lat, lon) float64 ...
#     E        (time, lat, lon) float64 ...
#     SMroot   (time, lat, lon) float64 ...
#     SMsurf   (time, lat, lon) float64 ...
#     stl1     (time, lat, lon) float64 ...
#     t2m      (time, lat, lon) float64 ...

# %%
for var in x.data_vars:
    print(var)
    x.isel(time=0)[var].plot()
    plt.show()
# Out:
# precip
# VHI
# E
# SMroot
# SMsurf
# stl1
# t2m

# %%
y
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 224, lon: 176, time: 1)
# Coordinates:
#   * time     (time) datetime64[ns] 2017-06-30
#   * lat      (lat) float32 -5.175003 -5.125 -5.075001 ... 5.924999 5.9749985
#   * lon      (lon) float32 33.524994 33.574997 33.625 ... 42.22499 42.274994
# Data variables:
#     VHI      (time, lat, lon) float64 ...

# %%
y.isel(time=0).VHI.plot()
